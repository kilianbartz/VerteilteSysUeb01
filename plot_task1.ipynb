# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("./ntp_accuracy_data.csv")
# convert "Local Time" to datetime
df["Local Time"] = pd.to_datetime(df["Local Time"], unit="s")
df
# Out:
#                         Local Time    Offset
# 0    2024-05-19 08:05:54.961766481  4.658922
# 1    2024-05-19 08:06:05.039629698  4.662429
# 2    2024-05-19 08:06:15.114198685  4.658497
# 3    2024-05-19 08:06:25.172848463  4.658275
# 4    2024-05-19 08:06:35.231027603  4.657644
# ...                            ...       ...
# 1075 2024-05-19 11:06:46.626257896  4.423679
# 1076 2024-05-19 11:07:01.721015692  4.424654
# 1077 2024-05-19 11:07:11.796554327  4.421920
# 1078 2024-05-19 11:07:21.965957642  4.425624
# 1079 2024-05-19 11:07:32.072578430  4.424341
#
# [1080 rows x 2 columns]

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
xformatter = mdates.DateFormatter('%H:%M')
# plot offset
plt.figure()
plt.plot(df["Local Time"], df["Offset"], label="Offset")
plt.xlabel("UTC Time")
plt.ylabel("Offset (s)")
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)
plt.legend()
plt.title("NTP Offset")
plt.savefig("ntp_offset_pc.png", dpi=100)
